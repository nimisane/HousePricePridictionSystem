# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('dataset/NewHouseDataset.csv')
dataset.head()
# Out:
#   What is your age? What is your gender?  \
# 0           46 - 55                 Male
# 1           56 - 65                 Male
# 2           36 - 45                 Male
# 3           36 - 45               Female
# 4           25 - 35                 Male
#
#   In which area do you stay in western line in Mumbai?  \
# 0                                            Andheri
# 1                                            Andheri
# 2                                            Andheri
# 3                                            Andheri
# 4                                            Andheri
#
#   Your yearly income in INR  \
# 0             7lakh - 9lakh
# 1            9lakh - 11lakh
# 2          11lakh and above
# 3          11lakh and above
# 4            9lakh - 11lakh
#
#   Are you planning to buy a new house in Mumbai(Western Line)?  \
# 0                                                 No
# 1                                                 No
# ...

# %%
dataset.shape
# Out:
# (129, 14)
